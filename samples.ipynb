# %%
import simpleNomo
import pandas as pd

# %%
path = "template.xlsx"

### check the excel template
pd.read_excel(path)
# Out:
#      feature  coef  min  max  type  position
# 0  intercept   NaN  NaN  NaN   NaN       NaN
# 1  threshold   NaN  NaN  NaN   NaN       NaN

# %%
### construct nomograms
cmv_nomo = simpleNomo.nomogram(path)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 ### construct nomograms
# ----> 2 cmv_nomo = simpleNomo.nomogram(path)
#
# File E:\software\softinstall\anaconda3\envs\Test_pytorch\Lib\site-packages\simpleNomo\__init__.py:223, in nomogram(path, result_title, fig_width, single_height, dpi, ax_para, tick_para, xtick_para, ylabel_para, total_point)
#     215 def nomogram(path, result_title="Positive Risk", fig_width=10, single_height=0.45, dpi=100,
#     216              ax_para = {"c":"black", "linewidth":1.3, "linestyle": "-"},
#     217              tick_para = {"direction": 'in',"length": 3, "width": 1.5,},
#    (...)    220                             "loc": "center", "color": "black", "rotation":"horizontal"},
#     221              total_point=100):
# --> 223     df, lm_intercept, threshold = generate_df_rank(path=path, total_point=total_point)
#     224     new = df["feature"].str.split(pat="_", expand=True)
#     226     if new.shape[1] == 1:
#
# File E:\software\softinstall\anaconda3\envs\Test_pytorch\Lib\site-packages\simpleNomo\__init__.py:31, in generate_df_rank(path, total_point)
#      28 df = df.sort_values(by = "abs_range*coef", ascending = False)
#      30 point = list(df["abs_range*coef"]/df["abs_range*coef"].shift(1))
# ---> 31 point[0] = 1
#      32 point = total_point*np.cumprod(point)
#      33 df["point"] = point
#
# IndexError: list assignment index out of range

# %%
### personalize the nomogram
cmv_nomo_personalize = simpleNomo.nomogram(path, 
                                           result_title="Risk for CMV", # change the title for the mapping graph
                                           fig_width=8, # change the width of the figure
                                           single_height=0.6, # change the height of each axis
                                           total_point=20,  # chage the maximum point of each variable
                                           dpi=80,  ### change the resolution
                                           ax_para = {"c":"green", "linewidth":1.3, "linestyle": "-"}, # chagne the paramters for each axis, for example here green
                                           xtick_para = {"fontsize": 10, "fontfamily": "times new roman"}, # change the parameters for the ticks of each axis, 
                                           ylabel_para = {"fontsize": 18, "fontname": "Songti Sc", "labelpad":150, 
                                                          "loc": "center", "color": "black", "rotation":"horizontal"},) # change the parameters for the variable name
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 ### personalize the nomogram
# ----> 2 cmv_nomo_personalize = simpleNomo.nomogram(path,
#       3                                            result_title="Risk for CMV", # change the title for the mapping graph
#       4                                            fig_width=8, # change the width of the figure
#       5                                            single_height=0.6, # change the height of each axis
#       6                                            total_point=20,  # chage the maximum point of each variable
#       7                                            dpi=80,  ### change the resolution
#       8                                            ax_para = {"c":"green", "linewidth":1.3, "linestyle": "-"}, # chagne the paramters for each axis, for example here green
#       9                                            xtick_para = {"fontsize": 10, "fontfamily": "times new roman"}, # change the parameters for the ticks of each axis,
#      10                                            ylabel_para = {"fontsize": 18, "fontname": "Songti Sc", "labelpad":150,
#      11                                                           "loc": "center", "color": "black", "rotation":"horizontal"},) # change the parameters for the variable name
#
# File E:\software\softinstall\anaconda3\envs\Test_pytorch\Lib\site-packages\simpleNomo\__init__.py:223, in nomogram(path, result_title, fig_width, single_height, dpi, ax_para, tick_para, xtick_para, ylabel_para, total_point)
#     215 def nomogram(path, result_title="Positive Risk", fig_width=10, single_height=0.45, dpi=100,
#     216              ax_para = {"c":"black", "linewidth":1.3, "linestyle": "-"},
#     217              tick_para = {"direction": 'in',"length": 3, "width": 1.5,},
#    (...)    220                             "loc": "center", "color": "black", "rotation":"horizontal"},
#     221              total_point=100):
# --> 223     df, lm_intercept, threshold = generate_df_rank(path=path, total_point=total_point)
#     224     new = df["feature"].str.split(pat="_", expand=True)
#     226     if new.shape[1] == 1:
#
# File E:\software\softinstall\anaconda3\envs\Test_pytorch\Lib\site-packages\simpleNomo\__init__.py:31, in generate_df_rank(path, total_point)
#      28 df = df.sort_values(by = "abs_range*coef", ascending = False)
#      30 point = list(df["abs_range*coef"]/df["abs_range*coef"].shift(1))
# ---> 31 point[0] = 1
#      32 point = total_point*np.cumprod(point)
#      33 df["point"] = point
#
# IndexError: list assignment index out of range
